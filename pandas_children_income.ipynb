# %% [markdown]
# <a href="https://colab.research.google.com/github/timur262007/first-project/blob/main/pandas_children_income.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
! gdown --id 1zLKWeJ_OZjxuK1P561-GopniCo_Pt_X6
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1zLKWeJ_OZjxuK1P561-GopniCo_Pt_X6
#
# but Gdown can't. Please check connections and permissions.

# %%
df = pd.read_csv('/content/age_children_income_1000.csv')

# %%
df['number_of_children'].value_counts()
# Out:
# number_of_children
# 0    658
# 1    226
# 2     94
# 3     20
# 5      1
# 4      1
# Name: count, dtype: int64

# %%
df['number_of_children'].value_counts(normalize=True)
# Out:
# number_of_children
# 0    0.658
# 1    0.226
# 2    0.094
# 3    0.020
# 5    0.001
# 4    0.001
# Name: proportion, dtype: float64

# %%
df['number_of_children'].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.histplot(df['number_of_children'], stat='probability')
# Out:
# <Axes: xlabel='number_of_children', ylabel='Probability'>

# %%
df['age'].hist()
# Out:
# <Axes: >

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df['age_bin'] = pd.cut(df['age'], 10)

# %%
df.groupby('age_bin')['age'].count()
# Out:
# /tmp/ipython-input-930591620.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_bin')['age'].count()
# age_bin
# (17.402, 22.107]     49
# (22.107, 26.766]    124
# (26.766, 31.425]    140
# (31.425, 36.084]    134
# (36.084, 40.743]    131
# (40.743, 45.401]    141
# (45.401, 50.06]     101
# (50.06, 54.719]     121
# (54.719, 59.378]     50
# (59.378, 64.037]      9
# Name: age, dtype: int64

# %%
df['number_of_children'].mean()
# Out:
# np.float64(0.483)

# %%
df['age'].mean()
# Out:
# np.float64(38.31925590719966)

# %%
salary = pd.Series([30,30,40,60,50])

# %%
salary
# Out:
# 0    30
# 1    30
# 2    40
# 3    60
# 4    50
# dtype: int64

# %%
salary.sort_values()
# Out:
# 0    30
# 1    30
# 2    40
# 4    50
# 3    60
# dtype: int64

# %%
(salary < 40).mean()
# Out:
# np.float64(0.4)

# %%
(df['income'] < df['income'].median()).mean()
# Out:
# np.float64(0.5)

# %%
(df['number_of_children'].value_counts()).head(1)
# Out:
# number_of_children
# 0    658
# Name: count, dtype: int64

# %%
df['income'].agg(['mean', 'median'])
# Out:
# mean      129415.746378
# median    114586.570939
# Name: income, dtype: float64

# %%
df['income'] < 114586.570939
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: income, Length: 1000, dtype: bool

# %%
df['income'].quantile(0.397)
# Out:
# np.float64(100039.61365702491)

# %%
df['pct'] = df['age'].rank(pct=True).head()

# %%
df.head()
# Out:
#          age  number_of_children         income           age_bin    pct
# 0  42.772420                   0   34396.537188  (40.743, 45.401]  0.639
# 1  29.561090                   0  183350.052521  (26.766, 31.425]  0.257
# 2  54.380735                   0   53689.856555   (50.06, 54.719]  0.936
# 3  42.551689                   0  109080.913926  (40.743, 45.401]  0.634
# 4  38.713080                   0  153612.343419  (36.084, 40.743]  0.521

# %%
(df['age'] < 42.772420).mean()
# Out:
# np.float64(0.638)

# %%
df.boxplot('age')
# Out:
# <Axes: >

# %%
df.boxplot('income')
# Out:
# <Axes: >

# %%
df['income'].describe()
# Out:
# count      1000.000000
# mean     129415.746378
# std       71251.620971
# min       21943.855414
# 25%       79594.040400
# 50%      114586.570939
# 75%      162888.891081
# max      678006.351857
# Name: income, dtype: float64

# %%
pd.options.display.max_rows = 100

# %%
df['income'].mean()
# Out:
# np.float64(129415.74637843431)

# %%
(df['income'] - df['income'].mean()).abs().mean()
# Out:
# np.float64(51910.29730549474)

# %%
np.sqrt(((df['income'] - df['income'].mean())**2).mean())
# Out:
# np.float64(71215.98624927517)

# %%
np.sqrt(((df['income'] - df['income'].mean())**2).sum() / (len(df)-1))
# Out:
# np.float64(71251.62097066913)

# %%
df[['age', 'income']]

# %%
df.groupby('age_bin')['income'].agg(['count', 'mean', 'median'])
# Out:
# /tmp/ipython-input-2890831652.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_bin')['income'].agg(['count', 'mean', 'median'])
#                   count           mean         median
# age_bin
# (17.402, 22.107]     49  104319.382165   88163.526875
# (22.107, 26.766]    124  133775.791324  125960.906191
# (26.766, 31.425]    140  130575.738767  114947.477353
# (31.425, 36.084]    134  135654.848704  118368.874351
# (36.084, 40.743]    131  134457.081592  128647.922872
# (40.743, 45.401]    141  139697.676942  123441.920529
# (45.401, 50.06]     101  142814.622910  122199.047306
# (50.06, 54.719]     121  112563.104588   95443.103632
# (54.719, 59.378]     50  104040.538214   91602.734609
# (59.378, 64.037]      9   77761.750813   78167.926251

# %%
df.groupby('age_bin')['income'].median().plot(rot=45, ylim=0)
# Out:
# /tmp/ipython-input-4264205019.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_bin')['income'].median().plot(rot=45, ylim=0)
# <Axes: xlabel='age_bin'>

# %%
df.plot(x='age', y='income', kind='scatter')
# Out:
# <Axes: xlabel='age', ylabel='income'>

# %%
df.groupby('number_of_children')['income'].median().plot()
# Out:
# <Axes: xlabel='number_of_children'>

# %%
np.random.binomial(1,0.5)
# Out:
# 0

# %%
result = []
for i in range(3):
  result.append(np.random.binomial(1,0.5))

# %%
result
# Out:
# [1, 1, 1]

# %%
pd.Series([0,1]).sample(1).values[0]
# Out:
# np.int64(1)

# %%
def coin_toss():
  return pd.Series([0,1]).sample(1).values[0]

# %%
pd.Series([1,2,3,4,5,6]).sample(10,replace=True).reset_index(drop=True)
# Out:
# 0    1
# 1    4
# 2    2
# 3    2
# 4    5
# 5    2
# 6    3
# 7    2
# 8    4
# 9    4
# dtype: int64

# %%
pd.Series(np.random.randint(1,6,size=1000)).value_counts()
# Out:
# 2    216
# 1    205
# 4    201
# 3    192
# 5    186
# Name: count, dtype: int64

# %%
np.random.binomial(1,0.1)
# Out:
# 0

# %%
pd.Series(np.random.normal(size=100000)).hist()
# Out:
# <Axes: >

# %%
uniform = pd.Series(np.random.uniform(size=100))

# %%
pd.Series(uniform.sample(1000,replace=True)).hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
u = np.random.randint(1,7,size=100000)

# %%
sns.histplot(u, stat='probability')
# Out:
# <Axes: ylabel='Probability'>

# %%
sns.ecdfplot(u)
# Out:
# <Axes: ylabel='Proportion'>

# %%
sns.histplot(pd.Series([1,2,3,4,4,5,6]).sample(10000,replace=True),stat='probability')
# Out:
# <Axes: ylabel='Probability'>

# %%
sns.ecdfplot(np.random.normal(size=10000))
# Out:
# <Axes: ylabel='Proportion'>

# %%
np.random.binomial(1,0.5,size = 2).sum()
# Out:
# np.int64(0)

# %%
n = 1000
result = []
for _ in range(n):
  result.append(np.random.binomial(1,0.5,size = 2).sum())

# %%
result[:10]
# Out:
# [np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(2),
#  np.int64(2),
#  np.int64(1),
#  np.int64(2),
#  np.int64(1),
#  np.int64(1)]

# %%
pd.Series(result).value_counts(normalize=True)
# Out:
# 1    0.549
# 0    0.244
# 2    0.207
# Name: proportion, dtype: float64
