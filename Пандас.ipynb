# %% [markdown]
# <a href="https://colab.research.google.com/github/timur262007/first-project/blob/main/%D0%9F%D0%B0%D0%BD%D0%B4%D0%B0%D1%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! gdown --id 1Z5B_i31aoIB0YnfW5xYdNaMLA561NZkq
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Z5B_i31aoIB0YnfW5xYdNaMLA561NZkq
# To: /content/archive.zip
# 100% 302k/302k [00:00<00:00, 117MB/s]

# %% [markdown]
# https://drive.google.com/file/d/1Z5B_i31aoIB0YnfW5xYdNaMLA561NZkq/view?usp=drive_link

# %% [markdown]
# /content/archive.zip

# %%
! unzip /content/archive.zip
# Out:
# Archive:  /content/archive.zip
#   inflating: aug_test.csv
#   inflating: aug_train.csv
#   inflating: sample_submission.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/aug_train.csv')

# %%
df.groupby('gender', dropna=False)[['city_development_index', 'training_hours']].agg(['count','mean'])
# Out:
#        city_development_index           training_hours
#                         count      mean          count       mean
# gender
# Female                   1238  0.844740           1238  65.636511
# Male                    13221  0.839053          13221  65.297633
# Other                     191  0.866272            191  63.869110
# NaN                      4508  0.792970           4508  65.559450

# %%
cooficient_corr = df['enrollee_id'].corr(df['target'])
cooficient_corr
# Out:
# np.float64(0.04947476259730248)

# %%
cooficient_corr1 = df['training_hours'].corr(df['target'])
cooficient_corr1
# Out:
# np.float64(-0.021577249713613304)

# %%
sns.regplot(x='city_development_index', y='training_hours', data=df)
plt.show()

# %%
grouped = df.groupby('gender')['city_development_index'].mean().reset_index()

# %%
grouped.plot.bar(x='gender', y='city_development_index', title='Столбчатая диаграмма по гендеру')
# Out:
# <Axes: title={'center': 'Столбчатая диаграмма по гендеру'}, xlabel='gender'>
